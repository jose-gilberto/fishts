# %%
import fishts
import fishts.transformers as t
from fishts.descriptors.time_series import extract_ts_descriptor
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
import imageio

# %%
transforms = t.Compose([
    t.ConvertColor(cv2.COLOR_BGR2GRAY),
    t.Resize(proportion_scale=True, g_measure=300),
    t.GaussianBlur(kernel_size=(5,5), sigma_x=0),
    t.Threshold(60, 255, cv2.THRESH_BINARY),
    t.CannyEdge(threshold_1=50, threshold_2=100),
    t.Dilate(kernel=None, iterations=1),
    t.Erode(kernel=None, iterations=1),
])

# %% [markdown]
# ## Apple Example

# %%
gif = imageio.imread('../data/mpeg/apple-1.gif')
image = cv2.cvtColor(gif, cv2.COLOR_GRAY2BGR)

plt.imshow(image)

# %%
transformed = transforms(image)

ts = extract_ts_descriptor(transformed, start_angle=0, end_angle=360, step=1)
x = np.arange(0, 360, 1)

fig, ax = plt.subplots(1, 1, figsize=(12, 4))

ax.plot(x, ts)
ax.set_ylim([0, max(transformed.shape)])

plt.show()

# %%
gif = imageio.imread('../data/mpeg/apple-2.gif')
image = cv2.cvtColor(gif, cv2.COLOR_GRAY2BGR)

plt.imshow(image)

# %%
transformed = transforms(image)

ts = extract_ts_descriptor(transformed, start_angle=0, end_angle=360, step=1)
x = np.arange(0, 360, 1)

fig, ax = plt.subplots(1, 1, figsize=(12, 4))

ax.plot(x, ts)
ax.set_ylim([0, max(transformed.shape)])

plt.show()

# %% [markdown]
# ## Key Example

# %%
gif = imageio.imread('../data/mpeg/key-1.gif')
image = cv2.cvtColor(gif, cv2.COLOR_GRAY2BGR)

plt.imshow(image)

# %%
transformed = transforms(image)

ts = extract_ts_descriptor(transformed, start_angle=0, end_angle=360, step=1)
x = np.arange(0, 360, 1)

fig, ax = plt.subplots(1, 1, figsize=(12, 4))

ax.plot(x, ts)
ax.set_ylim([0, max(transformed.shape)])

plt.show()

# %%
gif = imageio.imread('../data/mpeg/key-2.gif')
image = cv2.cvtColor(gif, cv2.COLOR_GRAY2BGR)

plt.imshow(image)

# %%
transformed = transforms(image)

ts = extract_ts_descriptor(transformed, start_angle=0, end_angle=360, step=1)
x = np.arange(0, 360, 1)

fig, ax = plt.subplots(1, 1, figsize=(12, 4))

ax.plot(x, ts)
ax.set_ylim([0, max(transformed.shape)])

plt.show()

# %% [markdown]
# ## Personal Car Example

# %%
gif = imageio.imread('../data/mpeg/personal_car-1.gif')
image = cv2.cvtColor(gif, cv2.COLOR_GRAY2BGR)

plt.imshow(image)

# %%
transformed = transforms(image)

ts = extract_ts_descriptor(transformed, start_angle=0, end_angle=360, step=1)
x = np.arange(0, 360, 1)

fig, ax = plt.subplots(1, 1, figsize=(12, 4))

ax.plot(x, ts)
ax.set_ylim([0, max(transformed.shape)])

plt.show()

# %%
gif = imageio.imread('../data/mpeg/personal_car-2.gif')
image = cv2.cvtColor(gif, cv2.COLOR_GRAY2BGR)

plt.imshow(image)

# %%
transformed = transforms(image)

ts = extract_ts_descriptor(transformed, start_angle=0, end_angle=360, step=1)
x = np.arange(0, 360, 1)

fig, ax = plt.subplots(1, 1, figsize=(12, 4))

ax.plot(x, ts)
ax.set_ylim([0, max(transformed.shape)])

plt.show()
